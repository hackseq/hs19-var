# %%
import pandas as pd
import numpy as np
import os
import json

# %%
files_coord_curves = [x for x in os.listdir('./') if x.startswith('coord_curve')]

# %%
file_coord_cells = 'coord_cells.csv'

# %%
num = 50

df_file_x = pd.read_csv(file_coord_cells,sep='\t')

# %%
df_file_x.head()
# Out:
#   Unnamed: 0    color        D0        D1        D2
# 0   HSPC_228  #eea113  0.004344  0.021246  0.011557
# 1   HSPC_231  #7c5246  0.009480  0.019687 -0.008528
# 2   HSPC_596  #7c5246  0.020829 -0.031262 -0.002839
# 3   Prog_484  #d84f40  0.005689  0.038430  0.006549
# 4   Prog_051  #286ee1 -0.056154 -0.015540 -0.026224

# %%
len(df_file_x)
# Out:
# 1656

# %%
c1 = np.linspace(df_file_x.iloc[0,0], df_file_x.iloc[-1,0], num)
c1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-eec9aebb590e> in <module>
# ----> 1 c1 = np.linspace(df_file_x.iloc[0,0], df_file_x.iloc[-1,0], num)
#       2 c1
#
# //anaconda3/lib/python3.7/site-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     133     # Convert float/complex array scalars to float, gh-3504
#     134     # and make sure one can use variables that have an __array_interface__, gh-6634
# --> 135     start = asanyarray(start) * 1.0
#     136     stop  = asanyarray(stop)  * 1.0
#     137
#
# TypeError: ufunc 'multiply' did not contain a loop with signature matching types dtype('<U32') dtype('<U32') dtype('<U32')

# %%
list_cells = []

for i in range(len(df_file_x)):
    dict_coord_cells = dict()
    dict_coord_cells['cell_id'] = df_file_x.iloc[i,0]
    dict_coord_cells['color'] = df_file_x.iloc[i,1]
    dict_coord_cells['x'] = df_file_x.iloc[i,2]
    dict_coord_cells['y'] = df_file_x.iloc[i,3]
    dict_coord_cells['z'] = df_file_x.iloc[i,4]
    list_cells.append(dict_coord_cells)

# %%
list_cells
# Out:
# [{'cell_id': 'HSPC_228',
#   'color': '#eea113',
#   'x': 0.004343737628121925,
#   'y': 0.021245845144664745,
#   'z': 0.011557351139668109},
#  {'cell_id': 'HSPC_231',
#   'color': '#7c5246',
#   'x': 0.009479582070506028,
#   'y': 0.019686814105225374,
#   'z': -0.008528452256962724},
#  {'cell_id': 'HSPC_596',
#   'color': '#7c5246',
#   'x': 0.02082885437164004,
#   'y': -0.031262218866034745,
#   'z': -0.002838974532953874},
#  {'cell_id': 'Prog_484',
#   'color': '#d84f40',
#   'x': 0.005689039037018868,
#   'y': 0.038429666904056935,
#   'z': 0.006549438964268857},
#  {'cell_id': 'Prog_051',
#   'color': '#286ee1',
#   'x': -0.056153760918627775,
#   'y': -0.015540397787008343,
#   'z': -0.02622436845138729},
#  {'cell_id': 'Prog_719',
#   'color': '#286ee1',
#   'x': -0.053428598047264166,
#   'y': -0.013589894588881926,
#   'z': -0.021422636010193303},
#  {'cell_id': 'Prog_074',
#   'color': '#286ee1',
#   'x': -0.024929739823763588,
#   'y': 0.003446025423057016,
# ...

# %%
num = 50

df_file_x = pd.read_csv(file_coord_cells,sep='\t')
c1 = np.linspace(df_file_x.iloc[0,0], df_file_x.iloc[-1,0], num)
c2 = np.linspace(df_file_x.iloc[0,1], df_file_x.iloc[-1,1], num)
c3 = np.linspace(df_file_x.iloc[0,2], df_file_x.iloc[-1,2], num)

for i in range(num):
    dict_coord_curves = dict()
    dict_coord_curves['branch_id'] = x[-9:-4]
    dict_coord_curves['pseudotime'] = i
    dict_coord_curves['x'] = c1[i]
    dict_coord_curves['y'] = c2[i]
    dict_coord_curves['z'] = c3[i]
    list_curves.append(dict_coord_curves)

num = 50
list_cells = []
# for x in files_coord_curves:
    df_file_x = pd.read_csv(file_coord_cells,sep='\t')
    c1 = np.linspace(df_file_x.iloc[0,0], df_file_x.iloc[-1,0], num)
    c2 = np.linspace(df_file_x.iloc[0,1], df_file_x.iloc[-1,1], num)
    c3 = np.linspace(df_file_x.iloc[0,2], df_file_x.iloc[-1,2], num)
    for i in range(num):
        dict_coord_curves = dict()
        dict_coord_curves['branch_id'] = x[-9:-4]
        dict_coord_curves['pseudotime'] = i
        dict_coord_curves['x'] = c1[i]
        dict_coord_curves['y'] = c2[i]
        dict_coord_curves['z'] = c3[i]
        list_curves.append(dict_coord_curves)

# %%
num = 50
list_curves = []
for x in files_coord_curves:
    df_file_x = pd.read_csv(x,sep='\t')
    c1 = np.linspace(df_file_x.iloc[0,0], df_file_x.iloc[-1,0], num)
    c2 = np.linspace(df_file_x.iloc[0,1], df_file_x.iloc[-1,1], num)
    c3 = np.linspace(df_file_x.iloc[0,2], df_file_x.iloc[-1,2], num)
    
    for i in range(num):
        dict_coord_curves = dict()
        dict_coord_curves['branch_id'] = x[-9:-4]
        dict_coord_curves['pseudotime'] = i
        dict_coord_curves['x'] = c1[i]
        dict_coord_curves['y'] = c2[i]
        dict_coord_curves['z'] = c3[i]
        list_curves.append(dict_coord_curves)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c7998815e967> in <module>
#       1 num = 50
#       2 list_curves = []
# ----> 3 for x in files_coord_curves:
#       4     df_file_x = pd.read_csv(x,sep='\t')
#       5     c1 = np.linspace(df_file_x.iloc[0,0], df_file_x.iloc[-1,0], num)
#
# NameError: name 'files_coord_curves' is not defined

# %%
list_curves
# Out:
# [{'branch_id': 'S3_S5',
#   'pseudotime': 0,
#   'x': -0.06593725135199813,
#   'y': -0.022338808438985724,
#   'z': -0.046025399083270205},
#  {'branch_id': 'S3_S5',
#   'pseudotime': 1,
#   'x': -0.0643846113199396,
#   'y': -0.021324456856536445,
#   'z': -0.04535541594681902},
#  {'branch_id': 'S3_S5',
#   'pseudotime': 2,
#   'x': -0.06283197128788105,
#   'y': -0.020310105274087168,
#   'z': -0.04468543281036784},
#  {'branch_id': 'S3_S5',
#   'pseudotime': 3,
#   'x': -0.06127933125582252,
#   'y': -0.019295753691637888,
#   'z': -0.04401544967391666},
#  {'branch_id': 'S3_S5',
#   'pseudotime': 4,
#   'x': -0.059726691223763985,
#   'y': -0.018281402109188608,
#   'z': -0.043345466537465474},
#  {'branch_id': 'S3_S5',
#   'pseudotime': 5,
#   'x': -0.05817405119170545,
#   'y': -0.017267050526739332,
#   'z': -0.042675483401014284},
#  {'branch_id': 'S3_S5',
#   'pseudotime': 6,
#   'x': -0.05662141115964692,
#   'y': -0.016252698944290052,
#   'z': -0.0420055002645631},
# ...

# %%
with open('cells.json', 'w') as f:
    json.dump(list_cells, f)
